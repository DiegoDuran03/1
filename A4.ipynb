# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoDuran03/1/blob/main/A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file1 = 'https://raw.githubusercontent.com/tec03/Datasets/main/datasets/adult.csv'
file2 = 'https://raw.githubusercontent.com/tec03/Datasets/main/datasets/antropometria-dataset.csv'

adult_df = pd.read_csv(file1)
antropometria_df = pd.read_csv(file2)

adult_df.head()
antropometria_df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
adult_head = adult_df.head()
antropometria_head = antropometria_df.head()

adult_head, antropometria_head
# Out:
# (   age          workclass  fnlwgt   education  education-num  \
#  0   39          State-gov   77516   Bachelors             13
#  1   50   Self-emp-not-inc   83311   Bachelors             13
#  2   38            Private  215646     HS-grad              9
#  3   53            Private  234721        11th              7
#  4   28            Private  338409   Bachelors             13
#
#          marital-status          occupation    relationship    race      sex  \
#  0        Never-married        Adm-clerical   Not-in-family   White     Male
#  1   Married-civ-spouse     Exec-managerial         Husband   White     Male
#  2             Divorced   Handlers-cleaners   Not-in-family   White     Male
#  3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
#  4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain  capital-loss  hours-per-week  native-country the label
# ...

# %%
pivot_peso_est = antropometria_df.pivot_table(values='peso', index='desc_ent', aggfunc='mean')

pivot_peso_genero_est = antropometria_df.pivot_table(values='peso', index='desc_ent', columns='sexo', aggfunc='mean')

pivot_peso_est_1 = pivot_peso_est.join(pivot_peso_genero_est, lsuffix='_avg', rsuffix='_sexo')

pivot_peso_est_1
# Out:
#                                       peso          1          2
# desc_ent
# AGUASCALIENTES                   66.357786  69.985381  63.254292
# BAJA CALIFORNIA                  68.467270  71.391818  65.893667
# BAJA CALIFORNIA SUR              71.809198  75.561015  68.168959
# CAMPECHE                         65.418475  68.622637  62.920493
# CHIAPAS                          57.613775  58.365222  57.096111
# CHIHUAHUA                        66.656005  68.892642  64.815295
# COAHUILA DE ZARAGOZA             68.154142  68.873094  67.467348
# COLIMA                           68.743648  70.998878  66.978393
# DISTRITO FEDERAL                 65.119273  69.460661  61.654128
# DURANGO                          66.354922  68.846451  64.400031
# GUANAJUATO                       63.936390  65.008000  63.100995
# GUERRERO                         60.466315  62.611437  58.899850
# HIDALGO                          59.995917  61.747958  58.972554
# ...

# %%
median_peso_sex1_jal = antropometria_df[(antropometria_df['desc_ent'] == 'JALISCO') & (antropometria_df['sexo'] == 1)]['peso'].median()
median_peso_sex1_jal
# Out:
# 65.5875

# %%
max_avg_peso_sex1 = pivot_peso_genero_est[1].max()
max_avg_peso_sex1
# Out:
# 75.5610153256705

# %%
adult_df['marital-status'] = adult_df['marital-status'].str.strip()
adult_df['education'] = adult_df['education'].str.strip()

# %%
filtered_data_corrected = adult_df[(adult_df['marital-status'] == 'Divorced') & (adult_df['education'] == 'HS-grad')]
avg_age_div_hs_grad_2 = filtered_data_corrected['age'].mean()
avg_age_div_hs_grad_2
# Out:
# 42.3639181649101

# %%
data_male_2 = adult_df[(adult_df['sex'] == 'Male') &
                                        (adult_df['marital-status'] == 'Married-AF-spouse') &
                                        (adult_df['education'] == 'Bachelors')]

# %%
med_hours_per_week_4 = data_male_2['hours-per-week'].median()
med_hours_per_week_4
# Out:
# nan

# %%
pivot_t_edu = adult_df.pivot_table(
    values=['age', 'hours-per-week'],
    index=['education', 'marital-status'],
    columns='sex',
    aggfunc='median'
)

pivot_t_edu
# Out:
#                                        age       hours-per-week
# sex                                 Female  Male         Female  Male
# education    marital-status
# 10th         Divorced                 45.0  39.0           40.0  40.0
#              Married-civ-spouse       32.0  48.0           40.0  40.0
#              Married-spouse-absent    39.0  49.0           40.0  40.0
#              Never-married            18.0  20.0           26.5  40.0
#              Separated                34.0  38.0           40.0  40.0
# ...                                    ...   ...            ...   ...
# Some-college Married-civ-spouse       38.0  42.0           40.0  40.0
#              Married-spouse-absent    31.0  37.0           40.0  40.0
#              Never-married            22.0  23.0           35.0  40.0
#              Separated                38.0  37.0           40.0  40.0
#              Widowed                  58.0  60.5           40.0  40.0
#
# [103 rows x 4 columns]

# %%
med_peso_sex1_gua = antropometria_df[(antropometria_df['desc_ent'] == 'GUANAJUATO') & (antropometria_df['sexo'] == 1)]['peso'].median()
med_peso_sex1_gua
# Out:
# 65.0625

# %%
min_avg_peso_sex2 = pivot_peso_genero_est[2].min()
min_avg_peso_sex2
# Out:
# 57.09611111111111

# %%
divorced_hs_grad = adult_df[(adult_df['marital-status'] == 'Divorced') & (adult_df['education'] == 'HS-grad')]

avghours_per_week_divorced_hs_grad = divorced_hs_grad['hours-per-week'].mean()
avghours_per_week_divorced_hs_grad
# Out:
# 40.668319900805955
