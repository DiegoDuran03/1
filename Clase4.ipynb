# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoDuran03/1/blob/main/Clase4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Slicing from Multi-Indexed DFs and Ploting

# %%
path = 'https://raw.githubusercontent.com/tec03/Datasets/main/datasets/multi_index.csv'

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(path,
               index_col=[0,1],
               header=[0,1])
df.head()
# Out:
#                          Night                                           Day  \
#                        Weather       Wind Max Temperature            Weather
# City   Date
# London 01/07/19         Shower  SW 16 mph              18             Shower
#        02/07/19     Heavy rain  SW 16 mph              17             Shower
#        03/07/19     Heavy rain  SW 16 mph              19  Scattered showers
#        04/07/19  Mostly cloudy  SW 16 mph              23      Mostly cloudy
# Oxford 01/07/19         Shower  SW 16 mph              19             Shower
#
#
#                       Wind Max Temperature
# City   Date
# London 01/07/19  SW 16 mph              28
#        02/07/19  SW 16 mph              29
#        03/07/19  SW 16 mph              29
#        04/07/19  SW 16 mph              31
# Oxford 01/07/19  SW 13 mph              25

# %%
df.columns
# Out:
# MultiIndex([('Night',         'Weather'),
#             ('Night',            'Wind'),
#             ('Night', 'Max Temperature'),
#             (  'Day',         'Weather'),
#             (  'Day',            'Wind'),
#             (  'Day', 'Max Temperature')],
#            )

# %%
df.index
# Out:
# MultiIndex([(   'London', '01/07/19'),
#             (   'London', '02/07/19'),
#             (   'London', '03/07/19'),
#             (   'London', '04/07/19'),
#             (   'Oxford', '01/07/19'),
#             (   'Oxford', '02/07/19'),
#             (   'Oxford', '03/07/19'),
#             (   'Oxford', '04/07/19'),
#             ('Cambridge', '01/07/19'),
#             ('Cambridge', '02/07/19'),
#             ('Cambridge', '03/07/19'),
#             ('Cambridge', '04/07/19')],
#            names=['City', 'Date'])

# %%
df.loc[:,('Day', 'Max Temperature')]
# Out:
# City       Date
# London     01/07/19    28
#            02/07/19    29
#            03/07/19    29
#            04/07/19    31
# Oxford     01/07/19    25
#            02/07/19    26
#            03/07/19    28
#            04/07/19    25
# Cambridge  01/07/19    24
#            02/07/19    21
#            03/07/19    22
#            04/07/19    22
# Name: (Day, Max Temperature), dtype: int64

# %%
df.loc['London',
        ('Day','Max Temperature')]
# Out:
# Date
# 01/07/19    28
# 02/07/19    29
# 03/07/19    29
# 04/07/19    31
# Name: (Day, Max Temperature), dtype: int64

# %%
df.sort_index(axis=1,inplace=True)
df.head()
# Out:
#                             Day                                         Night  \
#                 Max Temperature            Weather       Wind Max Temperature
# City   Date
# London 01/07/19              28             Shower  SW 16 mph              18
#        02/07/19              29             Shower  SW 16 mph              17
#        03/07/19              29  Scattered showers  SW 16 mph              19
#        04/07/19              31      Mostly cloudy  SW 16 mph              23
# Oxford 01/07/19              25             Shower  SW 13 mph              19
#
#
#                        Weather       Wind
# City   Date
# London 01/07/19         Shower  SW 16 mph
#        02/07/19     Heavy rain  SW 16 mph
#        03/07/19     Heavy rain  SW 16 mph
#        04/07/19  Mostly cloudy  SW 16 mph
# Oxford 01/07/19         Shower  SW 16 mph

# %%
df.sort_index(axis=0,inplace=True)
df.head()
# Out:
#                                Day                                \
#                    Max Temperature            Weather       Wind
# City      Date
# Cambridge 01/07/19              24             Shower  SW 16 mph
#           02/07/19              21  Scattered showers   E 20 mph
#           03/07/19              22  Scattered showers  SE 10 mph
#           04/07/19              22             Shower   S 25 mph
# London    01/07/19              28             Shower  SW 16 mph
#
#                              Night
#                    Max Temperature            Weather       Wind
# City      Date
# Cambridge 01/07/19              17             Shower  SW 16 mph
#           02/07/19              16  Scattered showers   E 20 mph
#           03/07/19              16  Scattered showers  SE 10 mph
#           04/07/19              16      Mostly cloudy   S 25 mph
# London    01/07/19              18             Shower  SW 16 mph

# %%
x = df.columns
x
# Out:
# MultiIndex([(  'Day', 'Max Temperature'),
#             (  'Day',         'Weather'),
#             (  'Day',            'Wind'),
#             ('Night', 'Max Temperature'),
#             ('Night',         'Weather'),
#             ('Night',            'Wind')],
#            )

# %%
type(x)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# ## 1. What is the average of Day Max Temperature?
# ## 2. What is the Max Temperature during
# ## 3. What is the max temp of Day and Night in cambridge and Oxford University?

# %%
df.loc[:,('Day','Max Temperature')].mean()
# Out:
# 25.833333333333332

# %%
df.loc[(slice(None),'03/07/19'),
       (slice(None),'Max Temperature')]
# Out:
#                                Day           Night
#                    Max Temperature Max Temperature
# City      Date
# Cambridge 03/07/19              22              16
# London    03/07/19              29              19
# Oxford    03/07/19              28              22

# %%
df.loc[['Cambridge', 'Oxford'],
       (slice(None),'Max Temperature')]
# Out:
#                                Day           Night
#                    Max Temperature Max Temperature
# City      Date
# Cambridge 01/07/19              24              17
#           02/07/19              21              16
#           03/07/19              22              16
#           04/07/19              22              16
# Oxford    01/07/19              25              19
#           02/07/19              26              19
#           03/07/19              28              22
#           04/07/19              25              21

# %%
favs=['Cambridge', 'Oxford']
favs2=['Day','Night']

# %%
df.loc[favs, (favs2,'Max Temperature')]
# Out:
#                                Day           Night
#                    Max Temperature Max Temperature
# City      Date
# Cambridge 01/07/19              24              17
#           02/07/19              21              16
#           03/07/19              22              16
#           04/07/19              22              16
# Oxford    01/07/19              25              19
#           02/07/19              26              19
#           03/07/19              28              22
#           04/07/19              25              21

# %%
df.columns.levels
# Out:
# FrozenList([['Day', 'Night'], ['Max Temperature', 'Weather', 'Wind']])

# %%
df.loc[('London','02/07/19'),('Day','Max Temperature')]
# Out:
# 29

# %%
df
# Out:
#                                Day                                \
#                    Max Temperature            Weather       Wind
# City      Date
# Cambridge 01/07/19              24             Shower  SW 16 mph
#           02/07/19              21  Scattered showers   E 20 mph
#           03/07/19              22  Scattered showers  SE 10 mph
#           04/07/19              22             Shower   S 25 mph
# London    01/07/19              28             Shower  SW 16 mph
#           02/07/19              29             Shower  SW 16 mph
#           03/07/19              29  Scattered showers  SW 16 mph
#           04/07/19              31      Mostly cloudy  SW 16 mph
# Oxford    01/07/19              25             Shower  SW 13 mph
#           02/07/19              26             Shower  SW 16 mph
#           03/07/19              28  Scattered showers  SW 16 mph
#           04/07/19              25             Shower  SW 14 mph
#
#                              Night
# ...

# %%
day_max_temp=df.loc[:,('Day','Max Temperature')]
day_max_temp
# Out:
# City       Date
# Cambridge  01/07/19    24
#            02/07/19    21
#            03/07/19    22
#            04/07/19    22
# London     01/07/19    28
#            02/07/19    29
#            03/07/19    29
#            04/07/19    31
# Oxford     01/07/19    25
#            02/07/19    26
#            03/07/19    28
#            04/07/19    25
# Name: (Day, Max Temperature), dtype: int64

# %%
type(day_max_temp)
# Out:
# pandas.core.series.Series

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(day_max_temp).set_title('Day Max Temperature')
# Out:
# Text(0.5, 1.0, 'Day Max Temperature')

# %%
sns.boxplot(x=day_max_temp)
# Out:
# <Axes: xlabel="('Day', 'Max Temperature')">
